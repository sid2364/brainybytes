# %%
# !pip install gymnasium pettingzoo matplotlib seaborn
# Out:
# Requirement already satisfied: gymnasium in ./learning_dynamics_env/lib/python3.12/site-packages (1.0.0)
# Requirement already satisfied: pettingzoo in ./learning_dynamics_env/lib/python3.12/site-packages (1.24.3)
# Requirement already satisfied: matplotlib in ./learning_dynamics_env/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: seaborn in ./learning_dynamics_env/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.21.0 in ./learning_dynamics_env/lib/python3.12/site-packages (from gymnasium) (2.1.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./learning_dynamics_env/lib/python3.12/site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./learning_dynamics_env/lib/python3.12/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./learning_dynamics_env/lib/python3.12/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./learning_dynamics_env/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./learning_dynamics_env/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./learning_dynamics_env/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./learning_dynamics_env/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./learning_dynamics_env/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in ./learning_dynamics_env/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./learning_dynamics_env/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./learning_dynamics_env/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in ./learning_dynamics_env/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in ./learning_dynamics_env/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./learning_dynamics_env/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in ./learning_dynamics_env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import sys
gym_location = "/home/sid/Study/brainybytes/Learning_Dynamics/env/lib/python3.12/site-packages"
sys.path.append(gym_location)

# %% [markdown]
# In this Notebook, you have to implement both Independent Learners (which are basically Q-Learners, but since the setting is again stateless, the updates simplify since there is no discount factor and no next time step) and Joint-Action Learners (Claus & Boutilier, 1998) in some coordination games. The code for the Independent Learner is copied from the notebook from last week, which you can just use as is.
#
# Implement code where it is asked (often as a comment).

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

import gymnasium as gym
from gymnasium import spaces
from pettingzoo import ParallelEnv

# %%
class Qlearner:
    """A Q-learning agent"""

    def __init__(
        self,
        action_size,
        state_size,
        learning_rate=0.0,
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.995,
    ):
        self.action_size = action_size
        self.state_size = state_size

        # initialize the Q-table:
        self.qtable = np.zeros((self.state_size, self.action_size))

        # define learning rate:
        if learning_rate == 0.0:
            self.dynamic_lr = True
            self.action_counter = np.zeros((self.state_size, self.action_size))
        else:
            self.dynamic_lr = False
            self.learning_rate = learning_rate

        # discount factor:
        self.gamma = gamma

        # Exploration parameters:
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay

        # tracking rewards/progress:
        self.rewards_this_episode = []  # during an episode, save every time step's reward
        self.episode_total_rewards = []  # each episode, sum the rewards, possibly with a discount factor
        self.average_episode_total_rewards = []  # the average (discounted) episode reward to indicate progress

        self.state_history = []
        self.action_history = []

    def reset_agent(self):
        self.qtable = np.zeros((self.state_size, self.action_size))

    def select_greedy(self, state):
        # np.argmax(self.qtable[state]) will select first entry if two or more Q-values are equal, but we want true randomness:
        print("qtable[state] and qtable[state].max", self.qtable[state], self.qtable[state].max())
        print("np.isclose", np.isclose(self.qtable[state], self.qtable[state].max()))
        return np.random.choice(np.flatnonzero(np.isclose(self.qtable[state], self.qtable[state].max())))

    def select_action(self, state):
        if np.random.rand() < self.epsilon:
            print("selecting random")
            action = random.randrange(self.action_size)
        else:
            print("selecting greedy")
            action = self.select_greedy(state)

        self.state_history.append(state)
        self.action_history.append(action)
        return action

    def update_epsilon(self):
        self.epsilon *= self.epsilon_decay
        self.epsilon = max(self.epsilon_min, self.epsilon)

    def update(self, state, action, new_state, reward, done, update_epsilon=True):
        if not self.dynamic_lr:
            lr = self.learning_rate
        else:
            self.action_counter[state, action] += 1
            lr = 1 / self.action_counter[state, action]

        # Q(s,a) <-- Q(s,a) + learning_rate [R + gamma * max_a' Q(s',a') - Q(s,a)]
        self.qtable[state, action] += lr * (reward + (not done) * self.gamma * np.max(self.qtable[new_state]) - self.qtable[state, action])

        self.rewards_this_episode.append(reward)

        if done:
            # track total reward:
            episode_reward = self._calculate_episode_reward(self.rewards_this_episode, discount=False)
            self.episode_total_rewards.append(episode_reward)

            k = len(self.average_episode_total_rewards) + 1  # amount of episodes that have passed
            self._calculate_average_episode_reward(k, episode_reward)

            if update_epsilon:
                self.update_epsilon()

            # reset the rewards for the next episode:
            self.rewards_this_episode = []

    def _calculate_episode_reward(self, rewards_this_episode, discount=False):
        if discount:
            return sum([self.gamma**i * reward for i, reward in enumerate(rewards_this_episode)])
        return sum(rewards_this_episode)

    def _calculate_average_episode_reward(self, k, episode_reward):
        if k > 1:  # running average is more efficient:
            average_episode_reward = (1 - 1 / k) * self.average_episode_total_rewards[-1] + episode_reward / k
        else:
            average_episode_reward = episode_reward
        self.average_episode_total_rewards.append(average_episode_reward)

    def print_rewards(self, episode, print_epsilon=True, print_q_table=True):
        print("Episode ", episode + 1)
        print("Total (discounted) reward of this episode: ", self.episode_total_rewards[episode])
        print("Average total reward over all episodes until now: ", self.average_episode_total_rewards[-1])

        print("Epsilon:", self.epsilon) if print_epsilon else None
        print("Q-table: ", self.qtable) if print_q_table else None

# %%
class JointActionLearner:
    """A joint action learner for matrix game environments."""
    
    def __init__(
        self,
        action_size,
        state_size,
        learning_rate=0.0,
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.995,
        opponent_action_size=2  # Added back explicitly
    ):
        self.action_size = action_size
        self.state_size = state_size
        self.opponent_action_size = opponent_action_size
        
        # Initialize Q-table with proper dimensions
        self.qtable = np.zeros((state_size, action_size, opponent_action_size))
        self.opponent_action_counts = np.ones(opponent_action_size)
        
        # Learning parameters
        if learning_rate == 0.0:
            self.dynamic_lr = True
            self.action_counter = np.zeros((state_size, action_size))
        else:
            self.dynamic_lr = False
            self.learning_rate = learning_rate
            
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        
        # Performance tracking
        self.rewards_this_episode = []
        self.episode_total_rewards = []
        self.average_episode_total_rewards = []
    
    def select_greedy(self, state):
        """Select action with highest expected value based on opponent model."""
        opponent_probs = self.opponent_action_counts / np.sum(self.opponent_action_counts)
        expected_values = np.sum(self.qtable[state] * opponent_probs, axis=1)
        return np.random.choice(np.flatnonzero(expected_values == expected_values.max()))
    
    def select_action(self, state):
        """Select action using epsilon-greedy strategy."""
        if np.random.rand() < self.epsilon:
            return random.randrange(self.action_size)
        return self.select_greedy(state)
    
    def update_opponent_distribution(self, opponent_action):
        """Update empirical distribution of opponent actions."""
        self.opponent_action_counts[opponent_action] += 1
    
    def update(self, state, action, new_state, reward, done):
        """Update Q-values based on reward and next state."""
        # Calculate learning rate
        if self.dynamic_lr:
            self.action_counter[state, action] += 1
            lr = 1.0 / self.action_counter[state, action]
        else:
            lr = self.learning_rate
            
        opponent_probs = self.opponent_action_counts / np.sum(self.opponent_action_counts)
        
        # Calculate future value
        if not done:
            expected_future_values = np.sum(self.qtable[new_state] * opponent_probs, axis=1)
            print("expected_future_values: ", expected_future_values)
            max_future_q = np.max(expected_future_values)
        else:
            max_future_q = 0
            
        # Update Q-table
        #print("lr * (reward + self.gamma * max_future_q)", lr * (reward + self.gamma * max_future_q))
        #print("self.qtable[state, action]", self.qtable[state, action])
        #print("lr * (reward + self.gamma * max_future_q - self.qtable[state, action])", lr * (reward + self.gamma * max_future_q - self.qtable[state, action]))
        
        self.qtable[state, action] = self.qtable[state, action] + \
            lr * (reward + self.gamma * max_future_q - self.qtable[state, action])
        
        # Track rewards and update epsilon
        self.rewards_this_episode.append(reward)
        
        if done:
            episode_reward = sum(self.rewards_this_episode)
            self.episode_total_rewards.append(episode_reward)
            
            k = len(self.episode_total_rewards)
            if k > 1:
                avg_reward = (1 - 1/k) * self.average_episode_total_rewards[-1] + episode_reward/k
            else:
                avg_reward = episode_reward
            self.average_episode_total_rewards.append(avg_reward)
            
            self.rewards_this_episode = []
            self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
            
    def print_rewards(self, episode, print_epsilon=True, print_q_table=True):
        print("Episode ", episode + 1)
        print("Total (discounted) reward of this episode: ", self.episode_total_rewards[episode])
        print("Average total reward over all episodes until now: ", self.average_episode_total_rewards[-1])
        print("Opponent action counts: ", self.opponent_action_counts)

        print("Epsilon:", self.epsilon) if print_epsilon else None
        print("Q-table: ", self.qtable) if print_q_table else None

# %%
class MatrixGame(ParallelEnv):
    metadata = {'render_modes': ['human']}

    def __init__(self, reward_matrix):
        self.agents = ["player_0", "player_1"]
        self.possible_agents = self.agents[:]
        self.reward_matrix = reward_matrix

        self.action_spaces = {agent: spaces.Discrete(reward_matrix.shape[0]) for agent in self.agents}
        self.observation_spaces = {agent: spaces.Discrete(1) for agent in self.agents}

    def reset(self, seed=None, options=None):
        self.agents = self.possible_agents[:]
        self.rewards = {agent: 0.0 for agent in self.agents}
        self.dones = {agent: False for agent in self.agents}
        self.infos = {agent: {} for agent in self.agents}
        self.state = None  # Stateless environment

        return {agent: 0 for agent in self.agents}  # Observations are dummy since the environment is stateless

    def step(self, actions):
        if not self.agents:
            return

        # Extract actions
        action_0 = actions[self.agents[0]]
        action_1 = actions[self.agents[1]]

        # Get rewards from the reward matrix
        reward_0, reward_1 = self.reward_matrix[action_0, action_1]

        # Update rewards
        self.rewards = {self.agents[0]: reward_0, self.agents[1]: reward_1}

        # Since this is a one-shot game, mark agents as done
        self.dones = {agent: True for agent in self.agents}
        self.truncateds = {agent: False for agent in self.agents}

        # No additional info in this case
        self.infos = {agent: {} for agent in self.agents}

        # Observations are dummy since the environment is stateless
        observations = {agent: 0 for agent in self.agents}

        return observations, self.rewards, self.dones, self.truncateds, self.infos

    def render(self):
        pass

    def close(self):
        pass

# %%
# Run the Independent Learner experiment:

# Define the Hill-Climbing game reward matrix
ASYMMETRIC_COORDINATION_GAME = np.array([[(11, 11), (0, 0)],  # Both pick action 0 -> high reward
                                        [(0, 0), (6, 6)]])   # Both pick action 1 -> moderate reward

# Define the optimal joint action (0, 0) is optimal in the Hill-Climbing game
optimal_joint_action = (0, 0)

# Number of trial runs
num_trials = 100
num_episodes = 1000

# Store the probability of optimal joint action for each episode, averaged across trials
optimal_action_probs_il = np.zeros(num_episodes)

for trial in range(num_trials):
    # Initialize environment and agents for Independent Learners (ILs)
    env = MatrixGame(reward_matrix=ASYMMETRIC_COORDINATION_GAME)

    agent_0_il = Qlearner(
        action_size=2,
        state_size=1,
        learning_rate=0.0,  # dynamic learning rate
        gamma=0.95,  # does not matter
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.99
    )

    agent_1_il = Qlearner(
        action_size=2,
        state_size=1,
        learning_rate=0.0,
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.99
    )

    # Keep track of the number of optimal actions for each episode
    optimal_actions_il = np.zeros(num_episodes)

    for episode in range(num_episodes):
        observations = env.reset()
        state = 0  # Single state in the Hill-Climbing game

        done = False

        # Agents take actions
        print(agent_0_il.qtable)
        action_0_il = agent_0_il.select_action(state)
        action_1_il = agent_1_il.select_action(state)

        actions = {"player_0": action_0_il, "player_1": action_1_il}

        # Step in the environment
        observations, rewards, dones, _, infos = env.step(actions)

        # Check if the agents selected the optimal joint action
        if (action_0_il, action_1_il) == optimal_joint_action:
            optimal_actions_il[episode] += 1

        # Update Q-tables
        agent_0_il.update(state, action_0_il, state, rewards["player_0"], dones["player_0"])
        agent_1_il.update(state, action_1_il, state, rewards["player_1"], dones["player_1"])
        
        #agent_0_il.print_rewards(episode)

    # Calculate the probability of optimal joint action over episodes for this trial
    optimal_action_probs_il += optimal_actions_il / num_trials  # Averaging across trials
# Out:
# [[0. 0.]]
# selecting random
# selecting random
# [[0. 0.]]
# selecting random
# selecting random
# [[11.  0.]]
# selecting random
# selecting random
# [[11.  3.]]
# selecting random
# selecting random
# [[11.  3.]]
# selecting random
# selecting random
# [[11.  4.]]
# selecting random
# selecting random
# [[11.  4.]]
# selecting random
# selecting random
# [[11.  3.]]
# selecting random
# selecting random
# [[11.   3.6]]
# selecting random
# selecting random
# [[8.25 3.6 ]]
# selecting random
# selecting random
# [[8.25 3.  ]]
# selecting random
# selecting random
# [[8.25       3.42857143]]
# selecting random
# selecting random
# [[8.8        3.42857143]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [6.28571429 4.8       ] 6.285714285714286
# np.isclose [ True False]
# [[9.16666667 3.42857143]]
# selecting random
# selecting random
# [[9.16666667 3.        ]]
# selecting random
# selecting random
# [[9.16666667 3.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [9.16666667 3.33333333] 9.166666666666668
# np.isclose [ True False]
# selecting random
# [[9.42857143 3.33333333]]
# selecting random
# selecting random
# [[9.42857143 3.6       ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [6.6        5.14285714] 6.6
# np.isclose [ True False]
# [[9.42857143 3.27272727]]
# selecting random
# selecting random
# [[8.25       3.27272727]]
# selecting random
# selecting random
# [[8.55555556 3.27272727]]
# selecting random
# selecting random
# [[8.55555556 3.        ]]
# selecting random
# selecting random
# [[8.8 3. ]]
# selecting random
# selecting random
# [[8.8        2.76923077]]
# selecting random
# selecting random
# [[9.         2.76923077]]
# selecting random
# selecting random
# [[9. 3.]]
# selecting random
# selecting random
# [[9.  2.8]]
# selecting random
# selecting random
# [[9. 3.]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [5.82352941 4.8       ] 5.823529411764706
# np.isclose [ True False]
# [[9.16666667 3.        ]]
# selecting random
# selecting random
# [[9.16666667 2.82352941]]
# selecting greedy
# qtable[state] and qtable[state].max [9.16666667 2.82352941] 9.166666666666666
# np.isclose [ True False]
# selecting random
# [[8.46153846 2.82352941]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [5.78947368 4.36363636] 5.789473684210526
# np.isclose [ True False]
# [[8.46153846 2.66666667]]
# selecting greedy
# qtable[state] and qtable[state].max [8.46153846 2.66666667] 8.461538461538462
# np.isclose [ True False]
# selecting random
# [[8.64285714 2.66666667]]
# selecting random
# selecting random
# [[8.8        2.66666667]]
# selecting greedy
# qtable[state] and qtable[state].max [8.8        2.66666667] 8.799999999999999
# np.isclose [ True False]
# selecting random
# [[8.25       2.66666667]]
# selecting greedy
# qtable[state] and qtable[state].max [8.25       2.66666667] 8.249999999999998
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [6. 4.] 5.999999999999999
# np.isclose [ True False]
# [[8.41176471 2.66666667]]
# selecting random
# selecting random
# [[7.94444444 2.66666667]]
# selecting random
# selecting random
# [[7.94444444 2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [7.94444444 2.52631579] 7.944444444444443
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [5.95833333 3.69230769] 5.958333333333332
# np.isclose [ True False]
# [[8.10526316 2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [8.10526316 2.52631579] 8.105263157894735
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [6.16       3.69230769] 6.159999999999999
# np.isclose [ True False]
# [[8.25       2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [8.25       2.52631579] 8.249999999999998
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [6.34615385 3.69230769] 6.346153846153846
# np.isclose [ True False]
# [[8.38095238 2.52631579]]
# selecting random
# selecting random
# [[8.5        2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [8.5        2.52631579] 8.499999999999998
# np.isclose [ True False]
# selecting random
# [[8.60869565 2.52631579]]
# selecting random
# selecting random
# [[8.25       2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [8.25       2.52631579] 8.25
# np.isclose [ True False]
# selecting random
# [[7.92       2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [7.92       2.52631579] 7.92
# np.isclose [ True False]
# selecting random
# [[8.03846154 2.52631579]]
# selecting random
# selecting random
# [[8.14814815 2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [8.14814815 2.52631579] 8.148148148148149
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.09677419 3.2       ] 7.096774193548386
# np.isclose [ True False]
# [[8.25       2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [8.25       2.52631579] 8.25
# np.isclose [ True False]
# selecting random
# [[8.34482759 2.52631579]]
# selecting greedy
# qtable[state] and qtable[state].max [8.34482759 2.52631579] 8.344827586206897
# np.isclose [ True False]
# selecting random
# [[8.43333333 2.52631579]]
# selecting random
# selecting random
# [[8.43333333 2.7       ]]
# selecting random
# selecting random
# [[8.43333333 2.85714286]]
# selecting random
# selecting random
# [[8.16129032 2.85714286]]
# selecting random
# selecting random
# [[7.90625    2.85714286]]
# selecting random
# selecting random
# [[7.90625    2.72727273]]
# selecting greedy
# qtable[state] and qtable[state].max [7.90625    2.72727273] 7.906250000000001
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.22857143 3.15789474] 7.228571428571427
# np.isclose [ True False]
# [[8.         2.72727273]]
# selecting greedy
# qtable[state] and qtable[state].max [8.         2.72727273] 8.0
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.33333333 3.15789474] 7.333333333333331
# np.isclose [ True False]
# [[8.08823529 2.72727273]]
# selecting greedy
# qtable[state] and qtable[state].max [8.08823529 2.72727273] 8.088235294117647
# np.isclose [ True False]
# selecting random
# [[7.85714286 2.72727273]]
# selecting random
# selecting random
# [[7.63888889 2.72727273]]
# selecting random
# selecting random
# [[7.43243243 2.72727273]]
# selecting random
# selecting random
# [[7.23684211 2.72727273]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.43243243 2.60869565] 7.432432432432431
# np.isclose [ True False]
# [[7.33333333 2.72727273]]
# selecting random
# selecting random
# [[7.425      2.72727273]]
# selecting random
# selecting random
# [[7.425      2.60869565]]
# selecting greedy
# qtable[state] and qtable[state].max [7.425      2.60869565] 7.425
# np.isclose [ True False]
# selecting random
# [[7.24390244 2.60869565]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.425 2.5  ] 7.424999999999998
# np.isclose [ True False]
# [[7.33333333 2.60869565]]
# selecting greedy
# qtable[state] and qtable[state].max [7.33333333 2.60869565] 7.333333333333334
# np.isclose [ True False]
# selecting random
# [[7.1627907  2.60869565]]
# selecting greedy
# qtable[state] and qtable[state].max [7.1627907  2.60869565] 7.162790697674419
# np.isclose [ True False]
# selecting random
# [[7.         2.60869565]]
# selecting greedy
# qtable[state] and qtable[state].max [7.         2.60869565] 7.0
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.51219512 2.30769231] 7.512195121951217
# np.isclose [ True False]
# [[7.08888889 2.60869565]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.5952381  2.30769231] 7.595238095238093
# np.isclose [ True False]
# [[7.08888889 2.5       ]]
# selecting random
# selecting random
# [[7.08888889 2.4       ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.25       2.30769231] 7.249999999999998
# np.isclose [ True False]
# [[7.08888889 2.30769231]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.08888889 2.30769231] 7.088888888888887
# np.isclose [ True False]
# [[7.08888889 2.22222222]]
# selecting greedy
# qtable[state] and qtable[state].max [7.08888889 2.22222222] 7.088888888888889
# np.isclose [ True False]
# selecting random
# [[6.93478261 2.22222222]]
# selecting greedy
# qtable[state] and qtable[state].max [6.93478261 2.22222222] 6.934782608695651
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [6.93478261 2.22222222] 6.9347826086956506
# np.isclose [ True False]
# [[7.0212766  2.22222222]]
# selecting greedy
# qtable[state] and qtable[state].max [7.0212766  2.22222222] 7.0212765957446805
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.0212766  2.22222222] 7.02127659574468
# np.isclose [ True False]
# [[7.10416667 2.22222222]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.10416667 2.22222222] 7.104166666666665
# np.isclose [ True False]
# [[7.10416667 2.14285714]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [6.95918367 2.22222222] 6.959183673469386
# np.isclose [ True False]
# [[7.18367347 2.14285714]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.04       2.22222222] 7.039999999999998
# np.isclose [ True False]
# [[7.18367347 2.06896552]]
# selecting greedy
# qtable[state] and qtable[state].max [7.18367347 2.06896552] 7.183673469387754
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [6.90196078 2.22222222] 6.901960784313724
# np.isclose [ True False]
# [[7.26       2.06896552]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [6.98076923 2.22222222] 6.980769230769229
# np.isclose [ True False]
# [[7.33333333 2.06896552]]
# selecting random
# selecting random
# [[7.19230769 2.06896552]]
# selecting random
# selecting random
# [[7.19230769 2.        ]]
# selecting greedy
# qtable[state] and qtable[state].max [7.19230769 2.        ] 7.192307692307691
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [6.92592593 2.14285714] 6.925925925925924
# np.isclose [ True False]
# [[7.26415094 2.        ]]
# selecting greedy
# qtable[state] and qtable[state].max [7.26415094 2.        ] 7.264150943396225
# np.isclose [ True False]
# selecting random
# [[7.12962963 2.        ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.         2.06896552] 6.999999999999998
# np.isclose [ True False]
# [[7.2 2. ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.07142857 2.06896552] 7.071428571428569
# np.isclose [ True False]
# [[7.26785714 2.        ]]
# selecting greedy
# qtable[state] and qtable[state].max [7.26785714 2.        ] 7.2678571428571415
# np.isclose [ True False]
# selecting random
# [[7.14035088 2.        ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.14035088 2.        ] 7.14035087719298
# np.isclose [ True False]
# [[7.14035088 1.93548387]]
# selecting greedy
# qtable[state] and qtable[state].max [7.14035088 1.93548387] 7.140350877192981
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.01724138 2.        ] 7.0172413793103425
# np.isclose [ True False]
# [[7.20689655 1.93548387]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.08474576 2.        ] 7.084745762711862
# np.isclose [ True False]
# [[7.20689655 1.875     ]]
# selecting random
# selecting random
# [[7.20689655 1.81818182]]
# selecting greedy
# qtable[state] and qtable[state].max [7.20689655 1.81818182] 7.206896551724137
# np.isclose [ True False]
# selecting random
# [[7.27118644 1.81818182]]
# selecting random
# selecting random
# [[7.33333333 1.81818182]]
# selecting greedy
# qtable[state] and qtable[state].max [7.33333333 1.81818182] 7.333333333333333
# np.isclose [ True False]
# selecting random
# [[7.21311475 1.81818182]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [6.98412698 1.93548387] 6.984126984126983
# np.isclose [ True False]
# [[7.27419355 1.81818182]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.046875   1.93548387] 7.046874999999999
# np.isclose [ True False]
# [[7.27419355 1.76470588]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [6.93846154 1.93548387] 6.938461538461538
# np.isclose [ True False]
# [[7.33333333 1.76470588]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.         1.93548387] 6.999999999999999
# np.isclose [ True False]
# [[7.33333333 1.71428571]]
# selecting greedy
# qtable[state] and qtable[state].max [7.33333333 1.71428571] 7.333333333333334
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [6.89552239 1.93548387] 6.8955223880597005
# np.isclose [ True False]
# [[7.390625   1.71428571]]
# selecting greedy
# qtable[state] and qtable[state].max [7.390625   1.71428571] 7.390625000000001
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [6.95588235 1.93548387] 6.955882352941176
# np.isclose [ True False]
# [[7.44615385 1.71428571]]
# selecting greedy
# qtable[state] and qtable[state].max [7.44615385 1.71428571] 7.446153846153847
# np.isclose [ True False]
# selecting random
# [[7.5        1.71428571]]
# selecting greedy
# qtable[state] and qtable[state].max [7.5        1.71428571] 7.500000000000001
# np.isclose [ True False]
# selecting random
# [[7.55223881 1.71428571]]
# selecting greedy
# qtable[state] and qtable[state].max [7.55223881 1.71428571] 7.55223880597015
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.12676056 1.93548387] 7.12676056338028
# np.isclose [ True False]
# [[7.60294118 1.71428571]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.18055556 1.93548387] 7.1805555555555545
# np.isclose [ True False]
# [[7.65217391 1.71428571]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.23287671 1.93548387] 7.232876712328766
# np.isclose [ True False]
# [[7.7        1.71428571]]
# selecting greedy
# qtable[state] and qtable[state].max [7.7        1.71428571] 7.7
# np.isclose [ True False]
# selecting random
# [[7.74647887 1.71428571]]
# selecting greedy
# qtable[state] and qtable[state].max [7.74647887 1.71428571] 7.746478873239437
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.33333333 1.93548387] 7.333333333333332
# np.isclose [ True False]
# [[7.79166667 1.71428571]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.38157895 1.93548387] 7.3815789473684195
# np.isclose [ True False]
# [[7.83561644 1.71428571]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.42857143 1.93548387] 7.428571428571427
# np.isclose [ True False]
# [[7.87837838 1.71428571]]
# selecting random
# selecting random
# [[7.87837838 1.66666667]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.37974684 1.93548387] 7.3797468354430364
# np.isclose [ True False]
# [[7.87837838 1.62162162]]
# selecting random
# selecting random
# [[7.87837838 1.57894737]]
# selecting greedy
# qtable[state] and qtable[state].max [7.87837838 1.57894737] 7.878378378378379
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.19753086 1.93548387] 7.19753086419753
# np.isclose [ True False]
# [[7.92       1.57894737]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.24390244 1.93548387] 7.24390243902439
# np.isclose [ True False]
# [[7.92       1.53846154]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.15662651 1.93548387] 7.156626506024096
# np.isclose [ True False]
# [[7.96052632 1.53846154]]
# selecting greedy
# qtable[state] and qtable[state].max [7.96052632 1.53846154] 7.960526315789474
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.20238095 1.93548387] 7.202380952380952
# np.isclose [ True False]
# [[8.         1.53846154]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.24705882 1.93548387] 7.247058823529411
# np.isclose [ True False]
# [[8.  1.5]]
# selecting greedy
# qtable[state] and qtable[state].max [8.  1.5] 8.0
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.1627907  1.93548387] 7.162790697674418
# np.isclose [ True False]
# [[8.03846154 1.5       ]]
# selecting greedy
# qtable[state] and qtable[state].max [8.03846154 1.5       ] 8.038461538461538
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.20689655 1.93548387] 7.206896551724137
# np.isclose [ True False]
# [[8.07594937 1.5       ]]
# selecting greedy
# qtable[state] and qtable[state].max [8.07594937 1.5       ] 8.075949367088608
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.25       1.93548387] 7.249999999999999
# np.isclose [ True False]
# [[8.1125 1.5   ]]
# selecting greedy
# qtable[state] and qtable[state].max [8.1125 1.5   ] 8.1125
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.29213483 1.93548387] 7.2921348314606735
# np.isclose [ True False]
# [[8.14814815 1.5       ]]
# selecting greedy
# qtable[state] and qtable[state].max [8.14814815 1.5       ] 8.148148148148149
# np.isclose [ True False]
# selecting random
# [[8.18292683 1.5       ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.37362637 1.93548387] 7.373626373626373
# np.isclose [ True False]
# [[8.21686747 1.5       ]]
# selecting greedy
# qtable[state] and qtable[state].max [8.21686747 1.5       ] 8.216867469879519
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.41304348 1.93548387] 7.413043478260869
# np.isclose [ True False]
# [[8.25 1.5 ]]
# selecting greedy
# qtable[state] and qtable[state].max [8.25 1.5 ] 8.250000000000002
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.4516129  1.93548387] 7.451612903225806
# np.isclose [ True False]
# [[8.28235294 1.5       ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.4893617  1.93548387] 7.489361702127659
# np.isclose [ True False]
# [[8.31395349 1.5       ]]
# selecting greedy
# qtable[state] and qtable[state].max [8.31395349 1.5       ] 8.313953488372096
# np.isclose [ True False]
# selecting random
# [[8.34482759 1.5       ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.5625     1.93548387] 7.562499999999999
# np.isclose [ True False]
# [[8.34482759 1.46341463]]
# selecting greedy
# qtable[state] and qtable[state].max [8.34482759 1.46341463] 8.3448275862069
# np.isclose [ True False]
# selecting random
# [[8.25       1.46341463]]
# selecting greedy
# qtable[state] and qtable[state].max [8.25       1.46341463] 8.250000000000004
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.48453608 1.875     ] 7.484536082474226
# np.isclose [ True False]
# [[8.28089888 1.46341463]]
# selecting greedy
# qtable[state] and qtable[state].max [8.28089888 1.46341463] 8.280898876404498
# np.isclose [ True False]
# selecting random
# [[8.18888889 1.46341463]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.52040816 1.81818182] 7.520408163265305
# np.isclose [ True False]
# [[8.18888889 1.42857143]]
# selecting greedy
# qtable[state] and qtable[state].max [8.18888889 1.42857143] 8.188888888888892
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.44444444 1.81818182] 7.444444444444444
# np.isclose [ True False]
# [[8.21978022 1.42857143]]
# selecting greedy
# qtable[state] and qtable[state].max [8.21978022 1.42857143] 8.219780219780223
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.48       1.81818182] 7.4799999999999995
# np.isclose [ True False]
# [[8.25       1.42857143]]
# selecting greedy
# qtable[state] and qtable[state].max [8.25       1.42857143] 8.250000000000004
# np.isclose [ True False]
# selecting random
# [[8.27956989 1.42857143]]
# selecting greedy
# qtable[state] and qtable[state].max [8.27956989 1.42857143] 8.279569892473122
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.54901961 1.81818182] 7.549019607843137
# np.isclose [ True False]
# [[8.30851064 1.42857143]]
# selecting greedy
# qtable[state] and qtable[state].max [8.30851064 1.42857143] 8.308510638297875
# np.isclose [ True False]
# selecting random
# [[8.33684211 1.42857143]]
# selecting greedy
# qtable[state] and qtable[state].max [8.33684211 1.42857143] 8.33684210526316
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.61538462 1.81818182] 7.615384615384615
# np.isclose [ True False]
# [[8.36458333 1.42857143]]
# selecting greedy
# qtable[state] and qtable[state].max [8.36458333 1.42857143] 8.364583333333336
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.64761905 1.81818182] 7.647619047619047
# np.isclose [ True False]
# [[8.39175258 1.42857143]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.67924528 1.81818182] 7.679245283018868
# np.isclose [ True False]
# [[8.41836735 1.42857143]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.71028037 1.81818182] 7.710280373831775
# np.isclose [ True False]
# [[8.41836735 1.39534884]]
# selecting greedy
# qtable[state] and qtable[state].max [8.41836735 1.39534884] 8.418367346938778
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.63888889 1.81818182] 7.638888888888888
# np.isclose [ True False]
# [[8.44444444 1.39534884]]
# selecting greedy
# qtable[state] and qtable[state].max [8.44444444 1.39534884] 8.444444444444446
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.66972477 1.81818182] 7.669724770642201
# np.isclose [ True False]
# [[8.47       1.39534884]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.7        1.81818182] 7.699999999999999
# np.isclose [ True False]
# [[8.4950495  1.39534884]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [7.72972973 1.81818182] 7.729729729729729
# np.isclose [ True False]
# [[8.4950495  1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.4950495  1.36363636] 8.495049504950497
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.66071429 1.81818182] 7.660714285714285
# np.isclose [ True False]
# [[8.51960784 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.51960784 1.36363636] 8.519607843137257
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.69026549 1.81818182] 7.690265486725663
# np.isclose [ True False]
# [[8.54368932 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.54368932 1.36363636] 8.543689320388351
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.71929825 1.81818182] 7.719298245614034
# np.isclose [ True False]
# [[8.56730769 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.56730769 1.36363636] 8.567307692307693
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.74782609 1.81818182] 7.747826086956521
# np.isclose [ True False]
# [[8.59047619 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.59047619 1.36363636] 8.590476190476192
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.77586207 1.81818182] 7.775862068965517
# np.isclose [ True False]
# [[8.61320755 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.61320755 1.36363636] 8.613207547169813
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.8034188  1.81818182] 7.803418803418803
# np.isclose [ True False]
# [[8.63551402 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.63551402 1.36363636] 8.63551401869159
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.83050847 1.81818182] 7.830508474576271
# np.isclose [ True False]
# [[8.65740741 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.65740741 1.36363636] 8.657407407407408
# np.isclose [ True False]
# selecting random
# [[8.67889908 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.67889908 1.36363636] 8.678899082568808
# np.isclose [ True False]
# selecting random
# [[8.7        1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.7        1.36363636] 8.700000000000001
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.90909091 1.81818182] 7.909090909090908
# np.isclose [ True False]
# [[8.72072072 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.72072072 1.36363636] 8.720720720720722
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.93442623 1.81818182] 7.934426229508196
# np.isclose [ True False]
# [[8.74107143 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.74107143 1.36363636] 8.74107142857143
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.95934959 1.81818182] 7.959349593495934
# np.isclose [ True False]
# [[8.76106195 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.76106195 1.36363636] 8.761061946902657
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [7.98387097 1.81818182] 7.983870967741934
# np.isclose [ True False]
# [[8.78070175 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.78070175 1.36363636] 8.780701754385968
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.008      1.81818182] 8.008
# np.isclose [ True False]
# [[8.8        1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.8        1.36363636] 8.800000000000002
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.03174603 1.81818182] 8.031746031746032
# np.isclose [ True False]
# [[8.81896552 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.81896552 1.36363636] 8.818965517241383
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.05511811 1.81818182] 8.05511811023622
# np.isclose [ True False]
# [[8.83760684 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.83760684 1.36363636] 8.83760683760684
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.078125   1.81818182] 8.078125
# np.isclose [ True False]
# [[8.8559322  1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.8559322  1.36363636] 8.855932203389832
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.10077519 1.81818182] 8.10077519379845
# np.isclose [ True False]
# [[8.87394958 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.87394958 1.36363636] 8.873949579831935
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.12307692 1.81818182] 8.123076923076923
# np.isclose [ True False]
# [[8.89166667 1.36363636]]
# selecting greedy
# qtable[state] and qtable[state].max [8.89166667 1.36363636] 8.89166666666667
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.14503817 1.81818182] 8.145038167938932
# np.isclose [ True False]
# [[8.90909091 1.36363636]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.16666667 1.81818182] 8.166666666666668
# np.isclose [ True False]
# [[8.90909091 1.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [8.90909091 1.33333333] 8.909090909090912
# np.isclose [ True False]
# selecting random
# [[8.92622951 1.33333333]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.12686567 1.81818182] 8.126865671641792
# np.isclose [ True False]
# [[8.94308943 1.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [8.94308943 1.33333333] 8.943089430894313
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.14814815 1.81818182] 8.148148148148149
# np.isclose [ True False]
# [[8.95967742 1.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [8.95967742 1.33333333] 8.959677419354842
# np.isclose [ True False]
# selecting random
# [[8.976      1.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [8.976      1.33333333] 8.976000000000003
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.18978102 1.81818182] 8.189781021897812
# np.isclose [ True False]
# [[8.99206349 1.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [8.99206349 1.33333333] 8.992063492063494
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.21014493 1.81818182] 8.210144927536232
# np.isclose [ True False]
# [[9.00787402 1.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [9.00787402 1.33333333] 9.007874015748033
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.23021583 1.81818182] 8.23021582733813
# np.isclose [ True False]
# [[9.0234375  1.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [9.0234375  1.33333333] 9.023437500000002
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.25       1.81818182] 8.25
# np.isclose [ True False]
# [[9.03875969 1.33333333]]
# selecting greedy
# qtable[state] and qtable[state].max [9.03875969 1.33333333] 9.038759689922482
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.26950355 1.81818182] 8.26950354609929
# np.isclose [ True False]
# [[9.05384615 1.33333333]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.28873239 1.81818182] 8.288732394366196
# np.isclose [ True False]
# [[9.05384615 1.30434783]]
# selecting greedy
# qtable[state] and qtable[state].max [9.05384615 1.30434783] 9.053846153846155
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.23076923 1.81818182] 8.23076923076923
# np.isclose [ True False]
# [[9.06870229 1.30434783]]
# selecting greedy
# qtable[state] and qtable[state].max [9.06870229 1.30434783] 9.068702290076338
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.25       1.81818182] 8.25
# np.isclose [ True False]
# [[9.08333333 1.30434783]]
# selecting greedy
# qtable[state] and qtable[state].max [9.08333333 1.30434783] 9.083333333333336
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.26896552 1.81818182] 8.26896551724138
# np.isclose [ True False]
# [[9.09774436 1.30434783]]
# selecting greedy
# qtable[state] and qtable[state].max [9.09774436 1.30434783] 9.097744360902258
# np.isclose [ True False]
# selecting random
# [[9.02985075 1.30434783]]
# selecting greedy
# qtable[state] and qtable[state].max [9.02985075 1.30434783] 9.029850746268659
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.28767123 1.76470588] 8.287671232876713
# np.isclose [ True False]
# [[9.04444444 1.30434783]]
# selecting random
# selecting random
# [[9.04444444 1.40425532]]
# selecting greedy
# qtable[state] and qtable[state].max [9.04444444 1.40425532] 9.044444444444446
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.30612245 1.88571429] 8.306122448979593
# np.isclose [ True False]
# [[9.05882353 1.40425532]]
# selecting greedy
# qtable[state] and qtable[state].max [9.05882353 1.40425532] 9.058823529411766
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.32432432 1.88571429] 8.324324324324326
# np.isclose [ True False]
# [[9.0729927  1.40425532]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.34228188 1.88571429] 8.342281879194633
# np.isclose [ True False]
# [[9.0729927 1.375    ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.0729927 1.375    ] 9.072992700729928
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.28666667 1.88571429] 8.286666666666669
# np.isclose [ True False]
# [[9.08695652 1.375     ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.08695652 1.375     ] 9.086956521739133
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.30463576 1.88571429] 8.304635761589406
# np.isclose [ True False]
# [[9.10071942 1.375     ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.10071942 1.375     ] 9.100719424460435
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.32236842 1.88571429] 8.322368421052634
# np.isclose [ True False]
# [[9.11428571 1.375     ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.33986928 1.88571429] 8.339869281045754
# np.isclose [ True False]
# [[9.12765957 1.375     ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.12765957 1.375     ] 9.127659574468089
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.35714286 1.88571429] 8.35714285714286
# np.isclose [ True False]
# [[9.14084507 1.375     ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.14084507 1.375     ] 9.14084507042254
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.37419355 1.88571429] 8.3741935483871
# np.isclose [ True False]
# [[9.15384615 1.375     ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.15384615 1.375     ] 9.153846153846159
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.39102564 1.88571429] 8.391025641025644
# np.isclose [ True False]
# [[9.16666667 1.375     ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.16666667 1.375     ] 9.166666666666671
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.40764331 1.88571429] 8.407643312101914
# np.isclose [ True False]
# [[9.17931034 1.375     ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.42405063 1.88571429] 8.424050632911396
# np.isclose [ True False]
# [[9.17931034 1.34693878]]
# selecting greedy
# qtable[state] and qtable[state].max [9.17931034 1.34693878] 9.179310344827591
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.37106918 1.88571429] 8.37106918238994
# np.isclose [ True False]
# [[9.19178082 1.34693878]]
# selecting greedy
# qtable[state] and qtable[state].max [9.19178082 1.34693878] 9.191780821917813
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.3875     1.88571429] 8.387500000000003
# np.isclose [ True False]
# [[9.20408163 1.34693878]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.40372671 1.88571429] 8.403726708074537
# np.isclose [ True False]
# [[9.20408163 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.20408163 1.32      ] 9.204081632653066
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.35185185 1.88571429] 8.351851851851855
# np.isclose [ True False]
# [[9.21621622 1.32      ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.36809816 1.88571429] 8.368098159509206
# np.isclose [ True False]
# [[9.22818792 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.22818792 1.32      ] 9.228187919463092
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.38414634 1.88571429] 8.384146341463417
# np.isclose [ True False]
# [[9.24 1.32]]
# selecting greedy
# qtable[state] and qtable[state].max [9.24 1.32] 9.240000000000006
# np.isclose [ True False]
# selecting random
# [[9.17880795 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.17880795 1.32      ] 9.178807947019873
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.4        1.83333333] 8.400000000000002
# np.isclose [ True False]
# [[9.19078947 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.19078947 1.32      ] 9.190789473684216
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.41566265 1.83333333] 8.415662650602412
# np.isclose [ True False]
# [[9.20261438 1.32      ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.43113772 1.83333333] 8.4311377245509
# np.isclose [ True False]
# [[9.21428571 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.21428571 1.32      ] 9.214285714285719
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.44642857 1.83333333] 8.446428571428575
# np.isclose [ True False]
# [[9.22580645 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.22580645 1.32      ] 9.225806451612907
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.46153846 1.83333333] 8.461538461538465
# np.isclose [ True False]
# [[9.23717949 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.23717949 1.32      ] 9.23717948717949
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.47647059 1.83333333] 8.476470588235298
# np.isclose [ True False]
# [[9.24840764 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.24840764 1.32      ] 9.248407643312106
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.49122807 1.83333333] 8.491228070175442
# np.isclose [ True False]
# [[9.25949367 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.25949367 1.32      ] 9.25949367088608
# np.isclose [ True False]
# selecting random
# [[9.27044025 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.27044025 1.32      ] 9.270440251572332
# np.isclose [ True False]
# selecting random
# [[9.2125 1.32  ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.2125 1.32  ] 9.212500000000004
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.52023121 1.78378378] 8.520231213872837
# np.isclose [ True False]
# [[9.22360248 1.32      ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.22360248 1.32      ] 9.223602484472053
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.53448276 1.78378378] 8.534482758620694
# np.isclose [ True False]
# [[9.2345679 1.32     ]]
# selecting greedy
# qtable[state] and qtable[state].max [9.2345679 1.32     ] 9.234567901234572
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.54857143 1.78378378] 8.548571428571433
# np.isclose [ True False]
# [[9.24539877 1.32      ]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.5625     1.78378378] 8.562500000000005
# np.isclose [ True False]
# [[9.24539877 1.29411765]]
# selecting greedy
# qtable[state] and qtable[state].max [9.24539877 1.29411765] 9.245398773006139
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.51412429 1.78378378] 8.514124293785317
# np.isclose [ True False]
# [[9.25609756 1.29411765]]
# selecting greedy
# qtable[state] and qtable[state].max [9.25609756 1.29411765] 9.256097560975613
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.52808989 1.78378378] 8.528089887640455
# np.isclose [ True False]
# [[9.26666667 1.29411765]]
# selecting greedy
# qtable[state] and qtable[state].max [9.26666667 1.29411765] 9.26666666666667
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.54189944 1.78378378] 8.541899441340787
# np.isclose [ True False]
# [[9.27710843 1.29411765]]
# selecting greedy
# qtable[state] and qtable[state].max [9.27710843 1.29411765] 9.277108433734943
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.55555556 1.78378378] 8.55555555555556
# np.isclose [ True False]
# [[9.28742515 1.29411765]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.56906077 1.78378378] 8.569060773480668
# np.isclose [ True False]
# [[9.28742515 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.28742515 1.26923077] 9.287425149700603
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.52197802 1.78378378] 8.521978021978027
# np.isclose [ True False]
# [[9.29761905 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.29761905 1.26923077] 9.297619047619051
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.53551913 1.78378378] 8.535519125683065
# np.isclose [ True False]
# [[9.30769231 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.30769231 1.26923077] 9.307692307692312
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.54891304 1.78378378] 8.548913043478265
# np.isclose [ True False]
# [[9.31764706 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.31764706 1.26923077] 9.317647058823534
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.56216216 1.78378378] 8.562162162162167
# np.isclose [ True False]
# [[9.32748538 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.32748538 1.26923077] 9.327485380116963
# np.isclose [ True False]
# selecting random
# [[9.3372093  1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.3372093  1.26923077] 9.337209302325585
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.58823529 1.78378378] 8.588235294117652
# np.isclose [ True False]
# [[9.34682081 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.34682081 1.26923077] 9.346820809248559
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.60106383 1.78378378] 8.60106382978724
# np.isclose [ True False]
# [[9.35632184 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.35632184 1.26923077] 9.356321839080463
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.61375661 1.78378378] 8.61375661375662
# np.isclose [ True False]
# [[9.36571429 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.36571429 1.26923077] 9.365714285714288
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.62631579 1.78378378] 8.62631578947369
# np.isclose [ True False]
# [[9.375      1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.375      1.26923077] 9.375000000000002
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.63874346 1.78378378] 8.638743455497387
# np.isclose [ True False]
# [[9.38418079 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.38418079 1.26923077] 9.384180790960453
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.65104167 1.78378378] 8.651041666666671
# np.isclose [ True False]
# [[9.39325843 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.39325843 1.26923077] 9.393258426966293
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.66321244 1.78378378] 8.663212435233165
# np.isclose [ True False]
# [[9.40223464 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.40223464 1.26923077] 9.402234636871508
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.67525773 1.78378378] 8.675257731958768
# np.isclose [ True False]
# [[9.41111111 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.41111111 1.26923077] 9.411111111111111
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.68717949 1.78378378] 8.687179487179492
# np.isclose [ True False]
# [[9.4198895  1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.4198895  1.26923077] 9.419889502762432
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.69897959 1.78378378] 8.69897959183674
# np.isclose [ True False]
# [[9.42857143 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.42857143 1.26923077] 9.42857142857143
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.7106599  1.78378378] 8.710659898477163
# np.isclose [ True False]
# [[9.43715847 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.43715847 1.26923077] 9.437158469945357
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.72222222 1.78378378] 8.722222222222227
# np.isclose [ True False]
# [[9.44565217 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.44565217 1.26923077] 9.445652173913047
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.73366834 1.78378378] 8.733668341708547
# np.isclose [ True False]
# [[9.45405405 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.45405405 1.26923077] 9.454054054054057
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.745      1.78378378] 8.745000000000005
# np.isclose [ True False]
# [[9.46236559 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.46236559 1.26923077] 9.462365591397852
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.75621891 1.78378378] 8.756218905472641
# np.isclose [ True False]
# [[9.47058824 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.47058824 1.26923077] 9.47058823529412
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.76732673 1.78378378] 8.767326732673272
# np.isclose [ True False]
# [[9.4787234  1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.4787234  1.26923077] 9.478723404255321
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.77832512 1.78378378] 8.778325123152714
# np.isclose [ True False]
# [[9.48677249 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.48677249 1.26923077] 9.48677248677249
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.78921569 1.78378378] 8.789215686274513
# np.isclose [ True False]
# [[9.49473684 1.26923077]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [8.8        1.78378378] 8.800000000000004
# np.isclose [ True False]
# [[9.5026178  1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.5026178  1.26923077] 9.502617801047123
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.81067961 1.78378378] 8.810679611650489
# np.isclose [ True False]
# [[9.51041667 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.51041667 1.26923077] 9.51041666666667
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.82125604 1.78378378] 8.821256038647347
# np.isclose [ True False]
# [[9.51813472 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.51813472 1.26923077] 9.51813471502591
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.83173077 1.78378378] 8.831730769230774
# np.isclose [ True False]
# [[9.5257732  1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.5257732  1.26923077] 9.525773195876292
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.84210526 1.78378378] 8.8421052631579
# np.isclose [ True False]
# [[9.53333333 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.53333333 1.26923077] 9.533333333333337
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.85238095 1.78378378] 8.852380952380956
# np.isclose [ True False]
# [[9.54081633 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.54081633 1.26923077] 9.540816326530615
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.86255924 1.78378378] 8.862559241706165
# np.isclose [ True False]
# [[9.54822335 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.54822335 1.26923077] 9.54822335025381
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.87264151 1.78378378] 8.872641509433967
# np.isclose [ True False]
# [[9.55555556 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.55555556 1.26923077] 9.555555555555559
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.88262911 1.78378378] 8.882629107981225
# np.isclose [ True False]
# [[9.56281407 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.56281407 1.26923077] 9.562814070351763
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.89252336 1.78378378] 8.892523364485987
# np.isclose [ True False]
# [[9.57       1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.57       1.26923077] 9.570000000000004
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [8.90232558 1.78378378] 8.902325581395354
# np.isclose [ True False]
# [[9.57711443 1.26923077]]
# selecting greedy
# qtable[state] and qtable[state].max [9.57711443 1.26923077] 9.5771144278607
# ...
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.35696517  1.6097561 ] 10.35696517412935
# np.isclose [ True False]
# [[10.58121827  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58121827  1.13793103] 10.581218274111679
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.35776398  1.6097561 ] 10.357763975155276
# np.isclose [ True False]
# [[10.58174905  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58174905  1.13793103] 10.581749049429662
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.35856079  1.6097561 ] 10.358560794044662
# np.isclose [ True False]
# [[10.58227848  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58227848  1.13793103] 10.582278481012663
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.35935564  1.6097561 ] 10.359355638166043
# np.isclose [ True False]
# [[10.58280657  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58280657  1.13793103] 10.582806573957022
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36014851  1.6097561 ] 10.360148514851481
# np.isclose [ True False]
# [[10.58333333  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58333333  1.13793103] 10.58333333333334
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36093943  1.6097561 ] 10.360939431396782
# np.isclose [ True False]
# [[10.58385876  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58385876  1.13793103] 10.583858764186639
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.3617284  1.6097561] 10.361728395061723
# np.isclose [ True False]
# [[10.58438287  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58438287  1.13793103] 10.58438287153653
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36251541  1.6097561 ] 10.362515413070279
# np.isclose [ True False]
# [[10.58490566  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58490566  1.13793103] 10.584905660377364
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36330049  1.6097561 ] 10.363300492610833
# np.isclose [ True False]
# [[10.58542714  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58542714  1.13793103] 10.585427135678398
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36408364  1.6097561 ] 10.364083640836403
# np.isclose [ True False]
# [[10.5859473   1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.5859473   1.13793103] 10.585947302383945
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36486486  1.6097561 ] 10.36486486486486
# np.isclose [ True False]
# [[10.58646617  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58646617  1.13793103] 10.586466165413539
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36564417  1.6097561 ] 10.365644171779136
# np.isclose [ True False]
# [[10.58698373  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58698373  1.13793103] 10.586983729662082
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36642157  1.6097561 ] 10.366421568627446
# np.isclose [ True False]
# [[10.5875      1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.5875      1.13793103] 10.587500000000004
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36719706  1.6097561 ] 10.367197062423497
# np.isclose [ True False]
# [[10.58801498  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58801498  1.13793103] 10.588014981273412
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36797066  1.6097561 ] 10.367970660146696
# np.isclose [ True False]
# [[10.58852868  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58852868  1.13793103] 10.588528678304243
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.36874237  1.6097561 ] 10.368742368742366
# np.isclose [ True False]
# [[10.5890411   1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.5890411   1.13793103] 10.589041095890416
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.3695122  1.6097561] 10.369512195121947
# np.isclose [ True False]
# [[10.58955224  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.58955224  1.13793103] 10.589552238805975
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37028015  1.6097561 ] 10.370280146163212
# np.isclose [ True False]
# [[10.59006211  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59006211  1.13793103] 10.590062111801247
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37104623  1.6097561 ] 10.371046228710458
# np.isclose [ True False]
# [[10.59057072  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59057072  1.13793103] 10.590570719602983
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37181045  1.6097561 ] 10.371810449574722
# np.isclose [ True False]
# [[10.59107807  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59107807  1.13793103] 10.591078066914504
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37257282  1.6097561 ] 10.372572815533976
# np.isclose [ True False]
# [[10.59158416  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59158416  1.13793103] 10.591584158415847
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37333333  1.6097561 ] 10.37333333333333
# np.isclose [ True False]
# [[10.592089    1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.592089    1.13793103] 10.592088998763911
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37409201  1.6097561 ] 10.374092009685226
# np.isclose [ True False]
# [[10.59259259  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59259259  1.13793103] 10.592592592592597
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37484885  1.6097561 ] 10.374848851269645
# np.isclose [ True False]
# [[10.59309494  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59309494  1.13793103] 10.593094944512952
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37560386  1.6097561 ] 10.375603864734295
# np.isclose [ True False]
# [[10.59359606  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59359606  1.13793103] 10.593596059113306
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37635706  1.6097561 ] 10.376357056694808
# np.isclose [ True False]
# [[10.59409594  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59409594  1.13793103] 10.594095940959415
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37710843  1.6097561 ] 10.377108433734934
# np.isclose [ True False]
# [[10.59459459  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59459459  1.13793103] 10.5945945945946
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.377858   1.6097561] 10.377858002406732
# np.isclose [ True False]
# [[10.59509202  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59509202  1.13793103] 10.595092024539882
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37860577  1.6097561 ] 10.378605769230763
# np.isclose [ True False]
# [[10.59558824  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59558824  1.13793103] 10.595588235294123
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.37935174  1.6097561 ] 10.379351740696272
# np.isclose [ True False]
# [[10.59608323  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59608323  1.13793103] 10.596083231334156
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38009592  1.6097561 ] 10.380095923261385
# np.isclose [ True False]
# [[10.59657702  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59657702  1.13793103] 10.596577017114921
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38083832  1.6097561 ] 10.380838323353288
# np.isclose [ True False]
# [[10.5970696   1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.5970696   1.13793103] 10.597069597069604
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38157895  1.6097561 ] 10.381578947368416
# np.isclose [ True False]
# [[10.59756098  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59756098  1.13793103] 10.597560975609763
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.3823178  1.6097561] 10.382317801672635
# np.isclose [ True False]
# [[10.59805116  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59805116  1.13793103] 10.598051157125465
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38305489  1.6097561 ] 10.383054892601427
# np.isclose [ True False]
# [[10.59854015  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59854015  1.13793103] 10.598540145985409
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38379023  1.6097561 ] 10.383790226460066
# np.isclose [ True False]
# [[10.59902795  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59902795  1.13793103] 10.599027946537067
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38452381  1.6097561 ] 10.384523809523804
# np.isclose [ True False]
# [[10.59951456  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.59951456  1.13793103] 10.599514563106803
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38525565  1.6097561 ] 10.385255648038045
# np.isclose [ True False]
# [[10.6         1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.6         1.13793103] 10.600000000000007
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38598575  1.6097561 ] 10.385985748218523
# np.isclose [ True False]
# [[10.60048426  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60048426  1.13793103] 10.600484261501217
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38671412  1.6097561 ] 10.38671411625148
# np.isclose [ True False]
# [[10.60096735  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60096735  1.13793103] 10.600967351874251
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38744076  1.6097561 ] 10.387440758293835
# np.isclose [ True False]
# [[10.60144928  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60144928  1.13793103] 10.601449275362326
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38816568  1.6097561 ] 10.388165680473369
# np.isclose [ True False]
# [[10.60193004  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60193004  1.13793103] 10.601930036188184
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38888889  1.6097561 ] 10.388888888888886
# np.isclose [ True False]
# [[10.60240964  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60240964  1.13793103] 10.602409638554223
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.38961039  1.6097561 ] 10.389610389610386
# np.isclose [ True False]
# [[10.60288809  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60288809  1.13793103] 10.602888086642604
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39033019  1.6097561 ] 10.390330188679242
# np.isclose [ True False]
# [[10.60336538  1.13793103]]
# selecting random
# selecting greedy
# qtable[state] and qtable[state].max [10.39104829  1.6097561 ] 10.391048292108358
# np.isclose [ True False]
# [[10.60384154  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60384154  1.13793103] 10.603841536614652
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39176471  1.6097561 ] 10.391764705882348
# np.isclose [ True False]
# [[10.60431655  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60431655  1.13793103] 10.604316546762597
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39247944  1.6097561 ] 10.392479435957693
# np.isclose [ True False]
# [[10.60479042  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60479042  1.13793103] 10.604790419161684
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39319249  1.6097561 ] 10.393192488262907
# np.isclose [ True False]
# [[10.60526316  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60526316  1.13793103] 10.605263157894745
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39390387  1.6097561 ] 10.393903868698706
# np.isclose [ True False]
# [[10.60573477  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60573477  1.13793103] 10.605734767025098
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39461358  1.6097561 ] 10.394613583138169
# np.isclose [ True False]
# [[10.60620525  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60620525  1.13793103] 10.606205250596666
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39532164  1.6097561 ] 10.395321637426896
# np.isclose [ True False]
# [[10.60667461  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60667461  1.13793103] 10.606674612634096
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39602804  1.6097561 ] 10.396028037383173
# np.isclose [ True False]
# [[10.60714286  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60714286  1.13793103] 10.607142857142865
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39673279  1.6097561 ] 10.39673278879813
# np.isclose [ True False]
# [[10.60760999  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60760999  1.13793103] 10.6076099881094
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.3974359  1.6097561] 10.397435897435894
# np.isclose [ True False]
# [[10.60807601  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60807601  1.13793103] 10.608076009501195
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39813737  1.6097561 ] 10.398137369033757
# np.isclose [ True False]
# [[10.60854093  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60854093  1.13793103] 10.608540925266912
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39883721  1.6097561 ] 10.398837209302322
# np.isclose [ True False]
# [[10.60900474  1.13793103]]
# selecting greedy
# qtable[state] and qtable[state].max [10.60900474  1.13793103] 10.6090047393365
# np.isclose [ True False]
# selecting greedy
# qtable[state] and qtable[state].max [10.39953542  1.6097561 ] 10.399535423925665
# np.isclose [ True False]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Plot the results
plt.plot(optimal_action_probs_il, label='Independent Learners (IL)')
plt.xlabel('Number of Interactions')
plt.ylabel('Probability of Choosing an Optimal Joint Action')
plt.title('Choosing Optimal Joint Actions')
plt.legend()
plt.grid(True)
plt.show()

# %%
optimal_action_probs_jal = np.zeros(num_episodes)

# Run multiple trial runs
for trial in range(num_trials):
    # Initialize environment and agents for Joint Action Learners (JALs)
    env = MatrixGame(reward_matrix=ASYMMETRIC_COORDINATION_GAME)

    # Initialize JAL agents instead of IL agents
    agent_0_jal = JointActionLearner(
        action_size=2,
        state_size=1,
        learning_rate=0.0,  # dynamic learning rate
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.99
    )

    agent_1_jal = JointActionLearner(
        action_size=2,
        state_size=1,
        learning_rate=0.0,
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.99
    )

    # Keep track of the number of optimal actions for each episode
    optimal_actions_jal = np.zeros(num_episodes)

    for episode in range(num_episodes):
        observations = env.reset()
        state = 0  # Single state in the Hill-Climbing game

        done = False

        # Agents take actions
        action_0_jal = agent_0_jal.select_action(state)
        action_1_jal = agent_1_jal.select_action(state)

        actions = {"player_0": action_0_jal, "player_1": action_1_jal}

        # Step in the environment
        observations, rewards, dones, _, infos = env.step(actions)

        # Check if the agents selected the optimal joint action
        if (action_0_jal, action_1_jal) == optimal_joint_action:
            optimal_actions_jal[episode] += 1
            
        # In your training loop:
        # Update Q-tables and opponent distributions
        agent_0_jal.update(state, action_0_jal, state, rewards["player_0"], dones["player_0"])
        agent_1_jal.update(state, action_1_jal, state, rewards["player_1"], dones["player_1"])

        # Update beliefs about opponent strategies
        agent_0_jal.update_opponent_distribution(action_1_jal)
        agent_1_jal.update_opponent_distribution(action_0_jal)
        
        #print("*"*20)
        

    # Calculate the probability of optimal joint action over episodes for this trial
    optimal_action_probs_jal += optimal_actions_jal / num_trials  # Averaging across trials

# %%
# Plot the results with both JAL and IL
plt.plot(optimal_action_probs_jal, label='Joint Action Learners (JAL)')
plt.plot(optimal_action_probs_il, label='Independent Learners (IL)')
plt.xlabel('Number of Interactions')
plt.ylabel('Probability of Choosing an Optimal Joint Action')
plt.title('Choosing Optimal Joint Actions')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_q_values_heatmap(agent, agent_name):
    for state in range(agent.state_size):
        plt.figure(figsize=(8, 6))
        q_values = agent.qtable[state]  # Get the Q-values for this state
        sns.heatmap(q_values, annot=True, cmap="coolwarm", cbar=True, xticklabels=[f"Opponent Action {i}" for i in range(agent.opponent_action_size)], yticklabels=[f"Action {i}" for i in range(agent.action_size)])
        plt.title(f"Q-Values for {agent_name} in State {state}")
        plt.xlabel("Opponent Actions")
        plt.ylabel("Agent Actions")
        plt.show()

# Example: Plot heatmaps for both JAL agents
plot_q_values_heatmap(agent_0_jal, "Agent 0 (JAL)")
plot_q_values_heatmap(agent_1_jal, "Agent 1 (JAL)")

# %% [markdown]
# Now, do the same for a fully symmetric coordination game as above. Also plot your results and explain them.

# %%
# Both coordinated actions (0, 0) and (1, 1) give reward 10
COORDINATION_MATRIX = np.array([[(10, 10), (0, 0)],  # (0, 0) is optimal
                                  [(0, 0), (10, 10)]])  # (1, 1) is also optimal

# %%
# Number of trial runs
num_trials = 100
num_episodes = 1000

# There are two optimal joint actions in the symmetric game: (0,0) and (1,1)
optimal_joint_actions = [(0, 0), (1, 1)]

# Store the probability of optimal joint actions for each episode, averaged across trials
optimal_action_probs_il_sym = np.zeros(num_episodes)
optimal_action_probs_jal_sym = np.zeros(num_episodes)

# Independent Learners experiment
for trial in range(num_trials):
    # Initialize environment and agents for Independent Learners (ILs)
    env = MatrixGame(reward_matrix=COORDINATION_MATRIX)

    agent_0_il = Qlearner(
        action_size=2,
        state_size=1,
        learning_rate=0.0,  # dynamic learning rate
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.99
    )

    agent_1_il = Qlearner(
        action_size=2,
        state_size=1,
        learning_rate=0.0,
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.99
    )

    # Keep track of the number of optimal actions for each episode
    optimal_actions_il = np.zeros(num_episodes)

    for episode in range(num_episodes):
        observations = env.reset()
        state = 0  # Single state

        # Agents take actions
        action_0_il = agent_0_il.select_action(state)
        action_1_il = agent_1_il.select_action(state)

        actions = {"player_0": action_0_il, "player_1": action_1_il}

        # Step in the environment
        observations, rewards, dones, _, infos = env.step(actions)

        # Check if the agents selected any optimal joint action
        if (action_0_il, action_1_il) in optimal_joint_actions:
            optimal_actions_il[episode] += 1

        # Update Q-tables
        agent_0_il.update(state, action_0_il, state, rewards["player_0"], dones["player_0"])
        agent_1_il.update(state, action_1_il, state, rewards["player_1"], dones["player_1"])

    optimal_action_probs_il_sym += optimal_actions_il / num_trials
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Joint Action Learners experiment
for trial in range(num_trials):
    # Initialize environment and agents for Joint Action Learners (JALs)
    env = MatrixGame(reward_matrix=COORDINATION_MATRIX)

    agent_0_jal = JointActionLearner(
        action_size=2,
        state_size=1,
        learning_rate=0.0,
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.99
    )

    agent_1_jal = JointActionLearner(
        action_size=2,
        state_size=1,
        learning_rate=0.0,
        gamma=0.95,
        epsilon=1.0,
        epsilon_min=0.01,
        epsilon_decay=0.99
    )

    optimal_actions_jal = np.zeros(num_episodes)

    for episode in range(num_episodes):
        observations = env.reset()
        state = 0

        action_0_jal = agent_0_jal.select_action(state)
        action_1_jal = agent_1_jal.select_action(state)

        actions = {"player_0": action_0_jal, "player_1": action_1_jal}

        observations, rewards, dones, _, infos = env.step(actions)

        if (action_0_jal, action_1_jal) in optimal_joint_actions:
            optimal_actions_jal[episode] += 1

        # Update Q-tables and opponent distributions
        agent_0_jal.update(state, action_0_jal, state, rewards["player_0"], dones["player_0"])
        agent_1_jal.update(state, action_1_jal, state, rewards["player_1"], dones["player_1"])

        # Update beliefs about opponent strategies
        agent_0_jal.update_opponent_distribution(action_1_jal)
        agent_1_jal.update_opponent_distribution(action_0_jal)

    optimal_action_probs_jal_sym += optimal_actions_jal / num_trials

# %%
# Plotting results
plt.figure(figsize=(10, 6))
plt.plot(optimal_action_probs_jal_sym, label='Joint Action Learners (JAL)')
plt.plot(optimal_action_probs_il_sym, label='Independent Learners (IL)')
plt.xlabel('Number of Interactions')
plt.ylabel('Probability of Choosing an Optimal Joint Action')
plt.title('Choosing Optimal Joint Actions in Symmetric Coordination Game')
plt.legend()
plt.grid(True)
plt.show()

# Plot Q-value heatmaps for final JAL agents
def plot_q_values_heatmap(agent, agent_name):
    for state in range(agent.state_size):
        plt.figure(figsize=(8, 6))
        q_values = agent.qtable[state]
        sns.heatmap(q_values, annot=True, cmap="coolwarm", cbar=True, 
                   xticklabels=[f"Opponent Action {i}" for i in range(agent.opponent_action_size)], 
                   yticklabels=[f"Action {i}" for i in range(agent.action_size)])
        plt.title(f"Q-Values for {agent_name} in State {state}")
        plt.xlabel("Opponent Actions")
        plt.ylabel("Agent Actions")
        plt.show()

# Plot heatmaps for both JAL agents
plot_q_values_heatmap(agent_0_jal, "Agent 0 (JAL)")
plot_q_values_heatmap(agent_1_jal, "Agent 1 (JAL)")
